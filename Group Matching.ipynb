# %%
import random
import itertools
import csv
import copy 
from itertools import combinations, chain
from random import shuffle
import math
import sys
import numpy as np

# %%
class Student:
    def __init__(self, name, email, netid, preferences, skill):
        self.name = name
        self.email = email
        self.netid = netid
        self.preferences = preferences
        self.skill = skill

# %%
class PM:
    def __init__(self, name, email, netid, preferences):
        self.name = name
        self.email = email
        self.netid = netid
        self.preferences = preferences

# %%
def print_person(s):
    print("Name: " + s.name)
    print("Email: " + s.email)
    print("NetID: " + s.netid)
    print("Preferences: ", end="")
    print(s.preferences)
    print(" ")

# %%
# READ CSV #################################################

# %%
# preferences for students in order
# [Game dev, finance, education, music, cs for good, mental health, computer vision, AI/ML/DL, NLP, data analytics]
# create a mape where row idx correlates to preferences option in csv
pref_map = {}
pref_map[5] = "gd"
pref_map[6] = "fin"
pref_map[7] = "edu"
pref_map[8] = "mus"
pref_map[9] = "c4g"
pref_map[10] = "mh"
pref_map[11] = "cv"
pref_map[12] = "ai"
pref_map[13] = "nlp"
pref_map[14] = "da"

# list of all students
student_list = []

# read csv of students with preferences and populate student_list
with open('FA20_Project_Preference.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
#             print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
#             based on how the preferences are formatted in the csv, we only need three
#             options. Using the map we get the student's three options in the preferences
#             array in the form [1st, 2nd, 3rd]
            preferences = [0, 0, 0]
            for i in range(5, 15):
                try: 
                    if row[i][0] == "1":
                        preferences[0] = pref_map[i]
                    if row[i][0] == "2":
                        preferences[1] = pref_map[i]
                    if row[i][0] == "3":
                        preferences[2] = pref_map[i]
                except:
                    continue
            student_list.append(Student(row[2], row[1], row[3], preferences, row[17]))
            
            
            
# list of all PMs
pm_list = []

# read csv of pm with preferences and populate pm_list
with open('FA20_Project_Preference_PM.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
#             print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
#             based on how the preferences are formatted in the csv, we only need three
#             options. Using the map we get the pm's three options in the preferences
#             array in the form [1st, 2nd, 3rd]
            preferences = [0, 0, 0]
            for i in range(5, 15):
                try: 
                    if row[i][0] == "1":
                        preferences[0] = pref_map[i]
                    if row[i][0] == "2":
                        preferences[1] = pref_map[i]
                    if row[i][0] == "3":
                        preferences[2] = pref_map[i]
                except:
                    continue
            pm_list.append(PM(row[2], row[1], row[3], preferences))

# %%
############################################################

# %%
# SORTING ALGORITHM #################################################

# %%
print("PM Num: " + str(len(pm_list)))
print("Student Num: " + str(len(student_list)))
team_size_calculation = math.floor(len(student_list)/len(pm_list))
print("Students per PM (rounding down): " + str(team_size_calculation))
# Out:
# PM Num: 28
# Student Num: 185
# Students per PM (rounding down): 6

# %%
# due to the complexity finding an optimal grouping is unrealistic so we will match students to PMs who
# listed a preference that was in the student's top two preferences. 

# If we find an 'optimal' solution, i.e. all students matched up with a PM who matches their
# top two choices then we end the script and print that optimal grouping (highly unlikely unfortunately)
perfect_match = False

# min_displaced stores the minimum number of students left without a group after 10,000 iterations. 
# we then create a grouping with the min students displaced and can hand place the displaced students
min_displaced = len(student_list)+1
min_variation = sys.maxsize
num_iterations = 10000

# best_so_far will hold the grouping with the least displaced students AND lowest groups size variance
best_so_far = []

# if we find a perfect match before the iterations are done we will use that directly
while not perfect_match and num_iterations > 0:
    
    num_iterations -= 1
    
    # will store the current grouping attempt
    pm_groups = []
    
    # we will take a copy of the pm list and shuffle the elements for this grouping attempt
    pm_list_test = pm_list.copy()
    shuffle(pm_list_test)
    
    # we will take a copy of the student list and shuffle the elements for this grouping attempt
    student_list_test = student_list.copy()
    shuffle(student_list_test)
    
    # if a student is in a group that fits their preferences they are deleted from circulation and added
    # to the placed set
    student_placed = set()
    
    # create groups for each pm
    for pm in pm_list_test:
        
        # curent pms group attempt
        curr_group = []
        
        # we want each group to be a max of math.ceil(len(student_list)/len(pm_list))
        num_members_needed = team_size_calculation
        
        # we find the next student who would fit this PM from the randomized list
        for student in student_list_test:
            for i in range(0, 2):
                # if the student's top two preferences fit the PM we add them to that group
                if student.preferences[i] in pm.preferences[:3]:
                    # add to pms group, add to placed set, remove from circulation
                    curr_group.append(student)
                    student_placed.add(student)
                    student_list_test.remove(student)
                    # team needs one less person now
                    num_members_needed -=1
                    break
            # if team is at max size we are done with this pm
            if num_members_needed == 0:
                break
        curr_group.insert(0, pm)
        pm_groups.append(curr_group)

    perfect_match = True
    displaced = 0
    for student in student_list:
        if student not in student_placed:
            # if any student is displaced then ths is not a perfect match
            perfect_match = False
            displaced += 1
     
    # update best grouping so far 
    if min_displaced > displaced:
        best_so_far = pm_groups
        min_displaced = displaced
    # if min_displaced is equal then pick the one with lower variance
    elif min_displaced == displaced:
        group_sizes = []
        for g in pm_groups:
            group_sizes.append(len(g))
        variance = np.var(group_sizes)
        if min_variation > variance:
            best_so_far = pm_groups
            min_variation = variance


# PRINT RESULTS
print("Num min displaced: ", end="")
print(min_displaced)

student_placed = set()

for i in range(len(best_so_far)):
    for s in best_so_far[i]:
        student_placed.add(s)

for s in student_list:
    if s not in student_placed:
        print(s.name, end=", ")
        print(s.netid, end=", ")
        print(s.preferences, end=", ")
        print("Coding skill level: " + str(s.skill))

        
for i in range(len(best_so_far)):
    print("#####################")
    print("Groups size: " + str(len(best_so_far[i])-1) + "/" + str(team_size_calculation))
    print("PM Name: ", end = "")
    for s in best_so_far[i]:
        print(s.name, end=", ")
        print(s.netid, end=", ")
        print(s.preferences, end=", ")
        try:
            print("Coding skill level: " + str(s.skill))
        except:
            print("\n")
# Out:
# Num min displaced: 17
# Akaash Kolachina, akaashk2, ['ai', 'c4g', 'fin'], Coding skill level: 2
# Aniket Tripathy, anikett2, ['mus', 'c4g', 'gd'], Coding skill level: 3
# Carlos Conley, cconley3, ['gd', 'da', 'ai'], Coding skill level: 4
# Chirag Mehta, chiragm3, ['ai', 'mus', 'da'], Coding skill level: 4
# Erika Huerta, ehuerta2, ['mh', 'c4g', 'edu'], Coding skill level: 3
# Gabriel Aaron, gaaron2, ['ai', 'fin', 'da'], Coding skill level: 3
# Gagan Kadadevarmath, gagan2, ['ai', 'gd', 'cv'], Coding skill level: 2
# Jackson Kennel, kennel2, ['nlp', 'cv', 'ai'], Coding skill level: 2
# Jonah Tjandra, jonahlt2, ['ai', 'cv', 'gd'], Coding skill level: 3
# Jordan, jzalwan2, ['da', 'ai', 'cv'], Coding skill level: 2
# Lisa Liu, lisaliu2, ['ai', 'cv', 'gd'], Coding skill level: 2
# Michal Juscinksi, michalj2, ['da', 'gd', 'ai'], Coding skill level: 3
# Priya Kumar, priyak5, ['ai', 'cv', 'nlp'], Coding skill level: 3
# Raghav, rsanand2, ['ai', 'gd', 'mus'], Coding skill level: 3
# Salman Shaheen, salmans3, ['c4g', 'cv', 'mh'], Coding skill level: 4
# Srikar Annapragada, vannap2, ['nlp', 'cv', 'ai'], Coding skill level: 3
# Ved, vedgs2, ['ai', 'nlp', 'cv'], Coding skill level: 3
# #####################
# Groups size: 6/6
# PM Name: Shagun Varma, svarma4, ['c4g', 'mh', 'edu'],
#
# Daniel Moon, dm32@illinois.edu, ['ai', 'c4g', 'nlp'], Coding skill level: 3
# Arman Rafati, arman3, ['edu', 'fin', 'c4g'], Coding skill level: 4
# Ananay Mathur, ananaym2, ['cv', 'edu', 'mus'], Coding skill level: 3
# Rayna Wuh, rwuh2, ['c4g', 'mh', 'fin'], Coding skill level: 1
# Jennifer Schwabe, schwabe6, ['gd', 'c4g', 'mh'], Coding skill level: 3
# Snigdha Gupta, snigdha8, ['da', 'c4g', 'cv'], Coding skill level: 3
# #####################
# Groups size: 6/6
# PM Name: Monika Para, mpara3, ['mh', 'edu', 'c4g'],
#
# Emi Brown, ecbrown2, ['gd', 'edu', 'c4g'], Coding skill level: 5
# Maaheen Maajed, mmaajed2, ['gd', 'mh', 'c4g'], Coding skill level: 1
# Larry Peng, larrylp2, ['fin', 'c4g', 'da'], Coding skill level: 3
# J Lee, jlee672, ['edu', 'c4g', 'ai'], Coding skill level: 3
# Jacob Harris, jacobah3, ['c4g', 'mus', 'gd'], Coding skill level: 4
# Myles McCarthy, mylestm2, ['c4g', 'ai', 'da'], Coding skill level: 3
# #####################
# Groups size: 6/6
# PM Name: Albert Li, yiliang6, ['c4g', 'mh', 'edu'],
#
# Owen Hayes, ohayes5, ['c4g', 'edu', 'ai'], Coding skill level: 2
# nishanth alladi, nalladi2, ['nlp', 'mh', 'edu'], Coding skill level: 4
# JiWoo Lee, jiwool4, ['c4g', 'ai', 'edu'], Coding skill level: 1
# Trisha Menon, tmenon3, ['c4g', 'edu', 'mh'], Coding skill level: 2
# Rachel Huang , 679598880, ['da', 'edu', 'ai'], Coding skill level: 2
# Salvador Ortiz, so14, ['c4g', 'da', 'fin'], Coding skill level: 1
# #####################
# Groups size: 6/6
# PM Name: Grace Robbins, Gcr3, ['edu', 'c4g', 'ai'],
#
# Zijing Wei, zijingw4, ['nlp', 'ai', 'da'], Coding skill level: 3
# Akshad Pai, avpai2, ['gd', 'ai', 'edu'], Coding skill level: 3
# Rafael Piacsek de Queiroz Ferreira, rafaelp5, ['ai', 'cv', 'gd'], Coding skill level: 4
# Jasmine Wang, jxwang3, ['ai', 'da', 'fin'], Coding skill level: 2
# Vineet Chinthakindi, vineetc2, ['ai', 'cv', 'da'], Coding skill level: 3
# David , davidy4, ['ai', 'gd', 'nlp'], Coding skill level: 3
# #####################
# Groups size: 6/6
# PM Name: Saket Vissapragada , saketv2, ['c4g', 'mh', 'edu'],
#
# Arjun Prabhu, arjunbp3, ['ai', 'c4g', 'gd'], Coding skill level: 2
# Prashant Naganaboyina, pkn3, ['c4g', 'gd', 'mh'], Coding skill level: 3
# Vivek Thatte, vthatt2, ['da', 'c4g', 'ai'], Coding skill level: 3
# Yiming Zhao, yiming14, ['mh', 'ai', 'nlp'], Coding skill level: 4
# Ethan Mui, ejmui2, ['ai', 'edu', 'mus'], Coding skill level: 2
# Syed Dayemi, sdayemi2, ['c4g', 'gd', 'edu'], Coding skill level: 3
# #####################
# Groups size: 6/6
# PM Name: William Eustis, weustis2, ['cv', 'edu', 'ai'],
#
# Neil Kaushikkar, neilk3, ['ai', 'da', 'nlp'], Coding skill level: 4
# Aadarsh Krishnan, akrish49, ['ai', 'cv', 'da'], Coding skill level: 2
# Rohan Sathe, rasathe2, ['ai', 'da', 'fin'], Coding skill level: 2
# Prajeet Sangamnerkar, Prajeet2, ['fin', 'ai', 'cv'], Coding skill level: 4
# Malcolm Forsyth, Johnmf4, ['da', 'cv', 'mus'], Coding skill level: 1
# Drshika Asher, drshika2, ['ai', 'nlp', 'c4g'], Coding skill level: 2
# #####################
# Groups size: 6/6
# PM Name: Isa Dash, anchald2, ['nlp', 'c4g', 'ai'],
#
# Aidan Wefel, awefel2, ['ai', 'gd', 'c4g'], Coding skill level: 4
# Shuchir Bhanage, bhanage2, ['gd', 'ai', 'da'], Coding skill level: 4
# Rishab Banthiya, rishabb3, ['fin', 'nlp', 'da'], Coding skill level: 3
# Linjia Long, linjial2, ['ai', 'da', 'gd'], Coding skill level: 4
# Meghna Mavila, mmavila3, ['ai', 'nlp', 'edu'], Coding skill level: 3
# Jeffrey Sun, js66, ['ai', 'gd', 'da'], Coding skill level: 2
# #####################
# Groups size: 6/6
# PM Name: Charles Xu, cyx2, ['gd', 'c4g', 'edu'],
#
# Jingbo Yang, 656421219, ['mus', 'gd', 'da'], Coding skill level: 3
# Xiyu Yao , xiyuz4, ['fin', 'gd', 'edu'], Coding skill level: 2
# Dharmil Jadav, djadav2, ['gd', 'da', 'nlp'], Coding skill level: 3
# Vaasay Farid, vfarid2, ['mus', 'gd', 'ai'], Coding skill level: 2
# Pranavkrishna Ramasubramanian, pr16, ['ai', 'gd', 'cv'], Coding skill level: 4
# Francesco Vial, 672345021, ['gd', 'ai', 'mus'], Coding skill level: 3
# #####################
# Groups size: 6/6
# PM Name: Raghav Saini, raghav3, ['ai', 'c4g', 'da'],
#
# Spencer Waldshan, saw7, ['ai', 'fin', 'gd'], Coding skill level: 4
# Kshitij Sinha, ksinha7@illinois.edu, ['da', 'cv', 'mus'], Coding skill level: 3
# Shreyansh Jain, sj44, ['cv', 'ai', 'gd'], Coding skill level: 1
# Andy Zhou, andyz3@illinois.edu, ['nlp', 'ai', 'cv'], Coding skill level: 3
# Daniel Dilan, ddilan2, ['cv', 'da', 'fin'], Coding skill level: 2
# Serlina Ku, sku6, ['ai', 'mus', 'fin'], Coding skill level: 2
# #####################
# Groups size: 6/6
# PM Name: Ahmed Hasan, aehasan2, ['da', 'ai', 'c4g'],
#
# Prithvi Balaji, Pbalaji3 , ['da', 'mus', 'gd'], Coding skill level: 3
# David Valencia Sanchez, dvalen25, ['ai', 'cv', 'edu'], Coding skill level: 5
# Colin Lu, colinyl2, ['ai', 'nlp', 'cv'], Coding skill level: 4
# Rylan Turner, rylanmt2, ['fin', 'ai', 'da'], Coding skill level: 4
# Carl Chen, hc27, ['fin', 'ai', 'da'], Coding skill level: 3
# Jiwung Cha, jiwungc2, ['ai', 'da', 'gd'], Coding skill level: 1
# #####################
# Groups size: 6/6
# PM Name: Albert Li, yiliang6, ['c4g', 'mh', 'edu'],
#
# Ishika Awachat, awachat2, ['da', 'c4g', 'edu'], Coding skill level: 3
# Rohit Chatterjee, rohitc3, ['c4g', 'edu', 'gd'], Coding skill level: 4
# Khangai Chinzorig, khangai2, ['fin', 'mh', 'da'], Coding skill level: 1
# Sana Madhavan, smadha8, ['nlp', 'c4g', 'ai'], Coding skill level: 2
# Ananya Rajagopal, apr5, ['c4g', 'edu', 'mh'], Coding skill level: 2
# Sabrina Tu, tu11, ['c4g', 'da', 'mh'], Coding skill level: 1
# #####################
# Groups size: 6/6
# PM Name: Ahmed Hasan, aehasan2, ['da', 'ai', 'c4g'],
#
# Noelle Crawford, noellec3, ['fin', 'da', 'cv'], Coding skill level: 3
# Tom Sui, tomsui2, ['ai', 'cv', 'da'], Coding skill level: 3
# Zihan Qiu, 668765813, ['da', 'cv', 'gd'], Coding skill level: 1
# Vasu Chalasani, sc83, ['ai', 'da', 'c4g'], Coding skill level: 3
# Meghan Lu, meghan7, ['da', 'ai', 'c4g'], Coding skill level: 2
# Manas Anand, manasa3, ['fin', 'ai', 'cv'], Coding skill level: 3
# #####################
# Groups size: 6/6
# PM Name: James, Jflemi9, ['fin', 'da', 'edu'],
#
# Brian Yoon, briancy2, ['fin', 'cv', 'nlp'], Coding skill level: 3
# Joseph Kuang, jjkuang2, ['da', 'fin', 'mus'], Coding skill level: 2
# Suyash Agrawal, suyasha2, ['ai', 'fin', 'da'], Coding skill level: 1
# Anakin Dey, anakind2, ['fin', 'da', 'cv'], Coding skill level: 1
# Sanya Nema, snema2, ['gd', 'da', 'mus'], Coding skill level: 3
# Eshaan, eshaan2, ['fin', 'da', 'nlp'], Coding skill level: 3
# #####################
# Groups size: 6/6
# PM Name: Shreya Sharma + Shruthi, ssharm90, ['ai', 'da', 'c4g'],
#
# Jebin John, jjohn261, ['fin', 'da', 'gd'], Coding skill level: 3
# Cameron Choy, cchoy2, ['gd', 'ai', 'cv'], Coding skill level: 5
# Ben Olaivar, olaivar3, ['ai', 'gd', 'cv'], Coding skill level: 3
# Ziqi Yang, ziqiy5, ['nlp', 'ai', 'gd'], Coding skill level: 1
# Param Mehta, paramum2, ['ai', 'fin', 'da'], Coding skill level: 4
# Marcos Lencinas, mvl3, ['ai', 'fin', 'c4g'], Coding skill level: 2
# #####################
# Groups size: 6/6
# PM Name: Theodore Li , ttl2, ['c4g', 'edu', 'mus'],
#
# Jiatai Ye, Jiataiy2, ['gd', 'mus', 'edu'], Coding skill level: 1
# Aabha Vyas, aabhav2, ['fin', 'mus', 'c4g'], Coding skill level: 3
# Phillip Burleigh, pburle2, ['gd', 'mus', 'c4g'], Coding skill level: 3
# Mateo Campoverde-Fordon, mateojc2, ['mus', 'da', 'ai'], Coding skill level: 4
# Daniel Rugutt, drugutt2, ['mus', 'da', 'edu'], Coding skill level: 3
# Neil Dey, neilrd2, ['gd', 'mus', 'mh'], Coding skill level: 3
# #####################
# Groups size: 6/6
# PM Name: Ajay Uppili Arasanipalai, aua2, ['ai', 'cv', 'nlp'],
#
# Stephanie Patterson, slp3, ['nlp', 'gd', 'ai'], Coding skill level: 2
# Neha Konjeti, konjeti3, ['ai', 'nlp', 'c4g'], Coding skill level: 3
# Yuqi Liu, 661740096, ['cv', 'nlp', 'ai'], Coding skill level: 2
# Parker Loepker, pgl3, ['gd', 'ai', 'c4g'], Coding skill level: 1
# Kavin Krishnasami, kavinsk2, ['da', 'ai', 'nlp'], Coding skill level: 3
# Varun Shroff, vshroff2, ['ai', 'da', 'fin'], Coding skill level: 1
# #####################
# Groups size: 6/6
# PM Name: Vishesh Gupta, vvgupta2, ['da', 'ai', 'mus'],
#
# Akul Gupta, Akulg3 , ['fin', 'ai', 'cv'], Coding skill level: 2
# Arnab Basu, arnabb3, ['ai', 'da', 'fin'], Coding skill level: 3
# Arnav Aggarwal, arnava4, ['fin', 'da', 'ai'], Coding skill level: 3
# Madhu Vakkadala, mv16, ['ai', 'gd', 'c4g'], Coding skill level: 3
# Sanjiv Iyer, sanjivi2, ['da', 'gd', 'fin'], Coding skill level: 4
# Rachael Wei, rlwei2, ['cv', 'ai', 'gd'], Coding skill level: 4
# #####################
# Groups size: 6/6
# PM Name: Aashna Mehta, Avmehta2, ['c4g', 'mh', 'cv'],
#
# Ernest Dane Pongos, epongo2, ['fin', 'cv', 'mh'], Coding skill level: 1
# Athena Fung, affung2, ['cv', 'ai', 'nlp'], Coding skill level: 3
# Jeremy Livshots, Jel7, ['ai', 'cv', 'da'], Coding skill level: 2
# Yu He, yuhe6, ['cv', 'ai', 'da'], Coding skill level: 1
# Alec Chen, acc11, ['ai', 'cv', 'nlp'], Coding skill level: 4
# Rustom Ichhaporia, rustomi2, ['ai', 'cv', 'nlp'], Coding skill level: 4
# #####################
# Groups size: 6/6
# PM Name: Sruthi Kilari + Shreya S, skilari2, ['ai', 'da', 'c4g'],
#
# Hanwen Li, hanwenl2, ['gd', 'da', 'mus'], Coding skill level: 1
# Grant Hale, grantrh2, ['fin', 'ai', 'mus'], Coding skill level: 2
# John Valdivieso, johnav3, ['ai', 'cv', 'gd'], Coding skill level: 2
# Nathaniel Smith, ngsmith, ['ai', 'gd', 'cv'], Coding skill level: 3
# Xavier Contreras, Xavierc2, ['gd', 'ai', 'cv'], Coding skill level: 2
# Dev Parekh, devbp2, ['ai', 'da', 'nlp'], Coding skill level: 2
# #####################
# Groups size: 6/6
# PM Name: dspatz2@illinois.edu, dspatz2, ['ai', 'c4g', 'da'],
#
# Aryan (AJ) Jain, aryanaj2, ['fin', 'da', 'ai'], Coding skill level: 1
# Ben Clarage, clarage2, ['fin', 'da', 'ai'], Coding skill level: 2
# Devang Rai, devangr2, ['ai', 'fin', 'da'], Coding skill level: 4
# mengfei wang, mengfei8, ['da', 'fin', 'cv'], Coding skill level: 3
# Anjali Kumar, anjalik4, ['ai', 'nlp', 'c4g'], Coding skill level: 2
# Archisha Gupta, ag52, ['nlp', 'ai', 'c4g'], Coding skill level: 2
# #####################
# Groups size: 6/6
# PM Name: Clara Wei, ziyuan3, ['nlp', 'mus', 'da'],
#
# Tianyun Zhang, tianyun9, ['ai', 'nlp', 'mus'], Coding skill level: 3
# Aria Wu, yuxinwu5, ['gd', 'da', 'cv'], Coding skill level: 2
# Charles Ancel, 657604114, ['gd', 'da', 'fin'], Coding skill level: 2
# Esha Dahal, edahal2, ['gd', 'da', 'fin'], Coding skill level: 1
# Anish Meka, anishm2, ['ai', 'da', 'nlp'], Coding skill level: 3
# Tanishq Khurana, tanishq3, ['da', 'nlp', 'fin'], Coding skill level: 1
# #####################
# Groups size: 6/6
# PM Name: Welby Moore, 661505282, ['mus', 'c4g', 'gd'],
#
# Hephzibah Manor, 675465856, ['fin', 'gd', 'da'], Coding skill level: 2
# Ananya Agarwal, ananyaa7, ['gd', 'cv', 'c4g'], Coding skill level: 3
# Alan Yao, alaney2, ['fin', 'gd', 'da'], Coding skill level: 2
# Emily Crawford, emilyc7, ['mus', 'ai', 'da'], Coding skill level: 2
# Jimmy Huang, jhuan35, ['fin', 'gd', 'ai'], Coding skill level: 3
# Tianze Li, tli94, ['gd', 'da', 'cv'], Coding skill level: 2
# #####################
# Groups size: 6/6
# PM Name: Kanav Bhatnagar, kanavb2, ['gd', 'ai', 'c4g'],
#
# Eugene Jang, emjang2, ['ai', 'gd', 'mus'], Coding skill level: 4
# Sri Abbineni, sra8, ['ai', 'fin', 'da'], Coding skill level: 4
# Gisella Kontaria, grk3, ['ai', 'fin', 'da'], Coding skill level: 1
# Nakul Iyer, nakuli2, ['fin', 'gd', 'ai'], Coding skill level: 4
# Lakshay Maharana, lakshay3, ['fin', 'ai', 'da'], Coding skill level: 4
# Purvansh Bal, pbal3, ['ai', 'da', 'c4g'], Coding skill level: 1
# #####################
# Groups size: 6/6
# PM Name: Sid Ajay, sajay2, ['mus', 'fin', 'edu'],
#
# Ivan Solis, Ivans2, ['cv', 'fin', 'da'], Coding skill level: 3
# Tony Wei , tongwei3, ['fin', 'cv', 'ai'], Coding skill level: 3
# Vansh Gupta, vanshg3, ['ai', 'fin', 'da'], Coding skill level: 3
# Joshua Joseph, Jtj4, ['fin', 'da', 'c4g'], Coding skill level: 1
# Lauren Beauban, beauban3, ['gd', 'mus', 'edu'], Coding skill level: 1
# Steven, sdimov2, ['da', 'mus', 'ai'], Coding skill level: 2
# #####################
# Groups size: 6/6
# PM Name: Shreya Basu, shreyab4, ['da', 'c4g', 'ai'],
#
# Gautham Sai Sayyaparaju, gautham2, ['da', 'ai', 'fin'], Coding skill level: 2
# Athena Zheng, athenaz2, ['ai', 'cv', 'nlp'], Coding skill level: 3
# Itay Gozalzani, Itayg2, ['ai', 'cv', 'gd'], Coding skill level: 2
# Ricky Zhao, Lkzhao2, ['ai', 'cv', 'da'], Coding skill level: 3
# Carter Smith, cwsmith5, ['da', 'cv', 'fin'], Coding skill level: 2
# Ayan Mallik, amallik2, ['ai', 'cv', 'da'], Coding skill level: 3
# #####################
# Groups size: 6/6
# PM Name: Ben Sutter, bsutter2, ['c4g', 'fin', 'edu'],
#
# Arnav Shah, arnavss2, ['ai', 'c4g', 'da'], Coding skill level: 3
# Charles Robling, robling2, ['fin', 'da', 'c4g'], Coding skill level: 1
# Shreya Singh, shreya15, ['fin', 'ai', 'da'], Coding skill level: 3
# Om Jivandas, ohj2, ['ai', 'fin', 'da'], Coding skill level: 3
# Anshul Bheemreddy , anshulb3, ['edu', 'da', 'gd'], Coding skill level: 3
# Haoting Zhang, haoting6, ['fin', 'da', 'ai'], Coding skill level: 3
# #####################
# Groups size: 6/6
# PM Name: Bryant Zhou, tianyiz8, ['edu', 'c4g', 'ai'],
#
# Ishani Tarafdar, itaraf2, ['ai', 'da', 'gd'], Coding skill level: 3
# Alex Desjardins, aed6, ['ai', 'da', 'edu'], Coding skill level: 2
# Saumil Thakore, saumilt2, ['ai', 'da', 'cv'], Coding skill level: 3
# Tanay Pareek, tpareek2, ['ai', 'nlp', 'c4g'], Coding skill level: 3
# Amit Sawhney, sawhney4, ['ai', 'da', 'c4g'], Coding skill level: 3
# Albert Zhao, albertz4, ['ai', 'cv', 'fin'], Coding skill level: 3
# #####################
# Groups size: 6/6
# PM Name: Linjia Long, linjial2, ['ai', 'da', 'gd'],
#
# Amith Hiremath, amithph2, ['cv', 'ai', 'nlp'], Coding skill level: 2
# Riya Jain, riyaj3, ['ai', 'nlp', 'da'], Coding skill level: 3
# Bryan Ge, bryanjg2, ['ai', 'da', 'mh'], Coding skill level: 2
# Aditya Joshi, Adityaj4, ['ai', 'gd', 'da'], Coding skill level: 3
# Victor Kao, vwkao2, ['gd', 'mus', 'ai'], Coding skill level: 3
# Serena Behera, behera3, ['nlp', 'ai', 'da'], Coding skill level: 3
